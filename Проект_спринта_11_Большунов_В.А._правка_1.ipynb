# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Василий, привет!👋</b>
#
# Меня зовут Кирилл Васильев, я буду ревьюером твоего проекта. Я предлагаю общаться на «ты», но если привычнее на «вы», просто скажи об этом!
#
# Я буду оставлять комментарии в твоем проекте. Пожалуйста, не удаляй их, они могут быть полезны в случае повторной проверки.
#
# Свои комментарии я буду обозначать <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным. Здесь же я могу давать советы и предложения.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# <br/>
# <div class="alert alert-info">
# Рекомендую для твоих комментариев использовать синий или любой другой цветной фон. Я постараюсь ничего не пропустить, но если комментарии будут выделены, то это мне очень поможет!
# </div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самостоятельно найти и исправить ее. На реальной работе твой руководитель будет поступать также. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку.

# %% [markdown]
# #  <center> <span style="color:black"> Модель для прогнозирования оттока клиентов для сервиса доставки кофе </span> </center>

# %% [markdown]
# Нам нужно построить модель бинарной классификации, которая спрогнозирует вероятность оттока каждого клиента в следующем месяце.
# Для решения задачи нам доступен датасет `coffee_churn_dataset.csv`:
#
# - `user_id` — идентификатор пользователя.
# - `days_since_last_order` — количество дней, прошедших с последнего заказа.
# - `order_frequency_month` — среднее число заказов в месяц.
# - `order_frequency_week` — среднее число заказов в неделю.
# - `avg_order_value` — средний чек, в рублях.
# - `median_order_value` — медианный чек, в рублях.
# - `total_spent_last_month` — сумма заказов за последний месяц.
# - `total_spent_last_week` — сумма заказов за последнюю неделю.
# - `discount_usage_rate` — доля заказов со скидкой за последний месяц.
# - `last_coffee_type` — сорт кофе, купленный пользователем в последний раз на момент сбора данных.
# - `preferred_roast` — предпочитаемый тип обжарки.
# - `milk_preference` — предпочитаемый тип молока.
# - `seasonal_menu_tried` — отметка о том, пробовал ли пользователь новейшее сезонное меню.
# - `coffee_bean_origin` — страна происхождения зерна.
# - `last_drink_size` — размер последнего напитка, купленного на момент сбора данных.
# - `subscription_status` — тип подписки пользователя.
# - `app_opens_per_week` — сколько раз за неделю пользователь в среднем открывал приложение доставки кофе.
# - `notifications_enabled` — включены ли у пользователя уведомления.
# - `review_rating_last_10` — средняя оценка последних на момент сбора данных десяти заказов клиента.
# - `review_rating_last_1` — оценка последнего на момент сбора данных заказа клиента.
# - `app_crashes_last_month` — сколько раз приложение зависало за последний месяц.
# - `seasons` — текущее время года.
# - `days_since_last_promo` — сколько дней прошло с последнего использования акции или промокода.
# - `phone_type` — тип устройства, с которого пользователь чаще всего совершал покупки.
# - `coffee_preference_change` — менялись ли вкусовые предпочтения пользователя.
# - `geo_location` — идентификатор региона пользователя.
# - `churn` — перестал ли пользователь пользоваться сервисом.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 Итак, решаем задачу бинарной классификации.
#
# Я бы рекомендовал выше чуть подробнее описать контекст, цель и задачи проекта. Это поможет быстро ввести в контекст потенциальных читателей работы, напрамер, тех, кому будем показывать проект в портфолио.

# %% [markdown]
# # <center> <span style="color:black"> Содержание </span> </center>

# %% [markdown]
# ## <center> <span style="color:black"> Этап 1. Подготовка среды и библиотек, знакомство с данными </span> </center>
# Загружаем необходимые для работы библиотеки, фиксируем random state для воспроизводимости результатов, после чего выводим датасет и основную информацию о нем, чтобы ознакомится с данными.

# %%
# !pip install category_encoders -q

# !pip install phik -q

# !pip install --upgrade scikit-learn -q

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Если добавить `-q` к загрузке, то логи выводиться не будут.
#
# `!pip install phik  -q`
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Привет, спасибо за ревью, приступаю к правкам! Поправил. Добавил -q к коду!
# </div>

# %%
# Импортируем нужные библиотеки
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
import category_encoders
import joblib
from phik import phik_matrix
from sklearn.model_selection import StratifiedKFold, train_test_split, cross_validate
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, average_precision_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder, FunctionTransformer, TargetEncoder
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# Фиксируем random_state

RANDOM_STATE = 42

# %%
# Выгружаем данные в датафрейм из датасета coffee_churn_dataset.csv

try:
    df = pd.read_csv (r'coffee_churn_dataset.csv',sep = ',', decimal = '.')
except:
    df = pd.read_csv ('/datasets/coffee_churn_dataset.csv',sep = ',', decimal = '.')

# Ознакомимся с датасетом, а также выведем основную информацию о нем
pd.set_option('display.max_columns', None)
df.sample(5)
# Out:
#          user_id  days_since_last_order  order_frequency_month  \
# 6805  user_06146                    3.0               2.422268
# 2841  user_06409                    NaN               5.976496
# 8961  user_01980                    1.0               2.037039
# 9788  user_01838                   13.0               3.876859
# 3059  user_07676                    6.0               2.907240
#
#       order_frequency_week  avg_order_value  median_order_value  \
# 6805              0.506889       236.708601          116.214542
# 2841              1.317349       684.094434          505.226584
# 8961              0.634282       503.567158          302.522713
# 9788              0.967283      2511.190819         1004.635453
# 3059              0.692789       848.129691          454.748362
#
#       total_spent_last_month  total_spent_last_week  discount_usage_rate  \
# 6805              265.278594              75.607966             0.246880
# 2841             2937.152802             847.137180             0.096694
# 8961              516.195633             214.949048             0.447784
# 9788             3783.596336            1146.252381             0.112005
# 3059             1198.042874             245.145942             0.255951
#
#      last_coffee_type preferred_roast milk_preference  seasonal_menu_tried  \
# 6805          arabica            dark           whole                  0.0
# 2841          arabica          medium          almond                  NaN
# 8961            blend          medium           whole                  1.0
# 9788            blend            dark             oat                  0.0
# 3059          arabica            dark           whole                  1.0
#
#      coffee_bean_origin last_drink_size subscription_status  \
# 6805          guatemala           large                 pro
# 2841              kenya           large               basic
# 8961          guatemala           large                 pro
# 9788           colombia          medium               basic
# 3059              kenya          medium               basic
#
#       app_opens_per_week  notifications_enabled  review_rating_last_10  \
# 6805           12.732028                    0.0               4.003576
# 2841            5.190699                    1.0               5.111127
# 8961           10.942915                    1.0               4.553145
# 9788           10.847659                    1.0               3.526933
# 3059            3.423900                    0.0               2.611948
#
#       review_rating_last_1  app_crashes_last_month seasons  \
# 6805              2.848412                     0.0  autumn
# 2841              4.138907                     1.0  summer
# 8961              5.221163                     NaN  spring
# 9788              5.807891                     1.0  summer
# 3059              4.607395                     1.0  autumn
#
#       days_since_last_promo phone_type  coffee_preference_change geo_location  \
# 6805                    3.0    android                       1.0      geo_100
# 2841                   46.0        ios                       0.0       geo_16
# 8961                   26.0        web                       0.0        geo_8
# 9788                    1.0        ios                       0.0        geo_1
# 3059                   33.0    android                       0.0        geo_2
#
#       churn
# 6805      0
# 2841      0
# 8961      0
# 9788      0
# 3059      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10450 entries, 0 to 10449
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   user_id                   10450 non-null  object
#  1   days_since_last_order     9505 non-null   float64
#  2   order_frequency_month     9850 non-null   float64
#  3   order_frequency_week      10062 non-null  float64
#  4   avg_order_value           9867 non-null   float64
#  5   median_order_value        9619 non-null   float64
#  6   total_spent_last_month    10156 non-null  float64
#  7   total_spent_last_week     9506 non-null   float64
#  8   discount_usage_rate       10053 non-null  float64
#  9   last_coffee_type          10192 non-null  object
#  10  preferred_roast           10334 non-null  object
#  11  milk_preference           9782 non-null   object
#  12  seasonal_menu_tried       9461 non-null   float64
#  13  coffee_bean_origin        9768 non-null   object
#  14  last_drink_size           9946 non-null   object
#  15  subscription_status       9512 non-null   object
#  16  app_opens_per_week        9554 non-null   float64
#  17  notifications_enabled     9913 non-null   float64
#  18  review_rating_last_10     9757 non-null   float64
#  19  review_rating_last_1      9593 non-null   float64
#  20  app_crashes_last_month    9729 non-null   float64
#  21  seasons                   9771 non-null   object
#  22  days_since_last_promo     9719 non-null   float64
#  23  phone_type                10114 non-null  object
#  24  coffee_preference_change  9840 non-null   float64
#  25  geo_location              10340 non-null  object
#  26  churn                     10450 non-null  int64
# dtypes: float64(16), int64(1), object(10)
# memory usage: 2.2+ MB

# %%
df.describe(include = 'all')
# Out:
#            user_id  days_since_last_order  order_frequency_month  \
# count        10450            9505.000000            9850.000000
# unique       10450                    NaN                    NaN
# top     user_00318                    NaN                    NaN
# freq             1                    NaN                    NaN
# mean           NaN               4.394214               4.025666
# std            NaN               4.858757               2.826144
# min            NaN               0.000000               0.011046
# 25%            NaN               1.000000               1.937767
# 50%            NaN               3.000000               3.381094
# 75%            NaN               6.000000               5.439363
# max            NaN              40.000000              27.389318
#
#         order_frequency_week  avg_order_value  median_order_value  \
# count           10062.000000      9867.000000         9619.000000
# unique                   NaN              NaN                 NaN
# top                      NaN              NaN                 NaN
# freq                     NaN              NaN                 NaN
# mean                0.930686      1063.741207          452.651500
# std                 0.657261       707.713396          258.657571
# min                -0.169131       -32.075932          -10.353340
# 25%                 0.445185       552.898663          262.908598
# 50%                 0.784839       898.643524          406.456818
# 75%                 1.262350      1406.332153          590.418070
# max                 6.302624      5901.965278         2189.101644
#
#         total_spent_last_month  total_spent_last_week  discount_usage_rate  \
# count             10156.000000            9506.000000         10053.000000
# unique                     NaN                    NaN                  NaN
# top                        NaN                    NaN                  NaN
# freq                       NaN                    NaN                  NaN
# mean               1946.132979             413.004760             0.284446
# std                2370.619590             445.634902             0.158735
# min                 -43.716463           -2290.559468             0.002162
# 25%                 629.680382             136.565833             0.159884
# 50%                1300.409757             288.277327             0.264583
# 75%                2481.650495             549.699420             0.387056
# max               79298.849570            8615.988952             0.887301
#
#        last_coffee_type preferred_roast milk_preference  seasonal_menu_tried  \
# count             10192           10334            9782          9461.000000
# unique                3               3               6                  NaN
# top             arabica          medium           whole                  NaN
# freq               6134            3458            2876                  NaN
# mean                NaN             NaN             NaN             0.701194
# std                 NaN             NaN             NaN             0.457759
# min                 NaN             NaN             NaN             0.000000
# 25%                 NaN             NaN             NaN             0.000000
# 50%                 NaN             NaN             NaN             1.000000
# 75%                 NaN             NaN             NaN             1.000000
# max                 NaN             NaN             NaN             1.000000
#
#        coffee_bean_origin last_drink_size subscription_status  \
# count                9768            9946                9512
# unique                  6               3                   4
# top              ethiopia          medium                none
# freq                 1690            4925                3803
# mean                  NaN             NaN                 NaN
# std                   NaN             NaN                 NaN
# min                   NaN             NaN                 NaN
# 25%                   NaN             NaN                 NaN
# 50%                   NaN             NaN                 NaN
# 75%                   NaN             NaN                 NaN
# max                   NaN             NaN                 NaN
#
#         app_opens_per_week  notifications_enabled  review_rating_last_10  \
# count          9554.000000            9913.000000            9757.000000
# unique                 NaN                    NaN                    NaN
# top                    NaN                    NaN                    NaN
# freq                   NaN                    NaN                    NaN
# mean             11.330895               0.753052               4.206709
# std              14.528887               0.431258               0.782212
# min               0.000000               0.000000               1.415526
# 25%               6.313628               1.000000               3.675543
# 50%               9.228383               1.000000               4.203555
# 75%              12.726649               1.000000               4.717292
# max             224.587876               1.000000               7.384425
#
#         review_rating_last_1  app_crashes_last_month seasons  \
# count            9593.000000             9729.000000    9771
# unique                   NaN                     NaN       4
# top                      NaN                     NaN  spring
# freq                     NaN                     NaN    2507
# mean                4.022460                1.013362     NaN
# std                 1.207883                1.010342     NaN
# min                -0.897000                0.000000     NaN
# 25%                 3.214157                0.000000     NaN
# 50%                 3.990032                1.000000     NaN
# 75%                 4.845225                2.000000     NaN
# max                 8.558443                7.000000     NaN
#
#         days_since_last_promo phone_type  coffee_preference_change  \
# count             9719.000000      10114               9840.000000
# unique                    NaN          3                       NaN
# top                       NaN    android                       NaN
# freq                      NaN       4611                       NaN
# mean                14.554584        NaN                  0.192480
# std                 15.308869        NaN                  0.394268
# min                  0.000000        NaN                  0.000000
# 25%                  4.000000        NaN                  0.000000
# 50%                 10.000000        NaN                  0.000000
# 75%                 20.000000        NaN                  0.000000
# max                140.000000        NaN                  1.000000
#
#        geo_location         churn
# count         10340  10450.000000
# unique          100           NaN
# top           geo_2           NaN
# freq           1629           NaN
# mean            NaN      0.060191
# std             NaN      0.237852
# min             NaN      0.000000
# 25%             NaN      0.000000
# 50%             NaN      0.000000
# 75%             NaN      0.000000
# max             NaN      1.000000

# %%
# Cоздаем копию датасета до преобразования для возможности проверить сделанные изменения после предобработки
temp = df.copy()

# %% [markdown]
# При первом рассмотрении видно, что данные соответствуют заявленным. Объем датасета составляет `10450` строк и `27` колонок, представляющих собой разнообразные признаки, включаю целевую переменную. Типы данных верны, датасет оформлен грамотно. Но, заметен определенный дисбаланс в распределении многих численных признаках, а также, практически во всех столбцах присутствуют пропуски, которые нам предстоит обработать.
# Также, заметны определенные аномалии в данных. Например, у некоторых числовых признаков присутствуют отрицательные значения. В ряде признаков такое возможно, например `avg_order_value`, где отрицательное значение может означать возврат. Но, в признаке `review_rating_last_1` это явно ошибка - рейтинг не может быть отрицательным.
#
# Многие признаки имеют сильный разброс значени и возможные выбросы. Их мы более детально проанализируем ниже, визуализировав распределение значений и построив боксплоты.
# Приступим к исследовательскому анализу данных, чтобы более детально ознакомиться с данными.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Здесь нужно дать какие-то пояснения по первому знакомству с данными. Все ли ок? Аномалии, пропуски?

# %% [markdown]
# <div class="alert alert-info">
# Добавил краткое описание данных при первом рассмотрении.
# </div>

# %% [markdown]
# ## <center> <span style="color:black"> Этап 2. Исследовательский анализ данных </span> </center>

# %% [markdown]
# Для реализации задачи бинарной классификации мы будем использовать датасет `coffee_churn_dataset.csv`. В нем собраны все необходимые для моделирования, признаки по каждому клиенту за последние 4 недели. Они представлены в виде готовой аналитической витрины с посчитанными мерами центральной тенденции: средними, медианами и т.д. В данных содержатся как числовые признаки, так и категориальные, охватывающие ряд предпочтений пользователей, такие как: предпочитаемый тип обжарки, предпочитаемый тип молока и т.д. В датасете `10450` строк и `27` столбцов, включая целевую переменную.
# При первом рассмотрении данные подготовлены достаточно хорошо, типы данных соответствуют значениям. Все дальнейшие решения мы будем принимать на основе исследовательского анализа.
#
# Приступаем к исследовательскому анализу.

# %% [markdown]
#  <center> <span style="color:black"> 1. Целевая переменная </span> </center>
# Начнем с целевой переменной. Посмотрим на особенности ее распределения, есть ли дисбаланс в данных.

# %%
# Выведем колчество положительных и отрицательных классов и визуализируем их в виде диаграммы

pos_class = df ['churn'].sum()
neg_class = df ['churn'].count() - pos_class
rat_pos_class = (pos_class / df ['churn'].count())

print (f'Ушедшие клиенты = {pos_class}')
print (f'Оставшиеся клиенты = {neg_class}')
print (f'Доля положительного класса = {rat_pos_class}')

df ['churn'].value_counts().plot (kind = 'bar',
                   rot = 0,
                   figsize = (3, 3))

plt.title ('Распределение классов целевой переменной')
plt.xlabel ('Класс')
plt.ylabel ('Число пользователей')
plt.grid()

plt.show()
# Out:
# Ушедшие клиенты = 629
# Оставшиеся клиенты = 9821
# Доля положительного класса = 0.060191387559808615

# %% [markdown]
# Наблюдается сильный дисбаланс классов. Большинство пользователей остается на сервисе и лишь `629` клиентов за период сбора данных перестало им пользоваться. В связи с этим, на этапе разделения данных по выборкам будем использовать стратификацию, для сохранения пропорций.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 Дисбаланс есть и он существенный, впрочем это ожидаемо для задачи оттока

# %% [markdown]
# <center> <span style="color:black"> 2. Признаки </span> </center>
# В нашем датасете присутствует достаточно большое число разнообразных признаков описывающих поведение и предпочтения пользователей. Некоторые из них выглядят избыточными или потенциально бесполезными для анализа вероятности ухода клиента (churn). Это:
#
# - `user_id` - идентификаторы пользователей не несут смысловой нагрузки для моделирования. Их лучше исключить;
#
#
# Удалим дэтот признакк после проверки датасета на дубликаты.
#
# Остальные признаки, потенциально, могут быть полезными и нести важную для модели информацию. Оставим их все, а в двльнейшем посмотри на значимость их для модели и примем соответствующие решения.

# %% [markdown]
# <center> <span style="color:black"> 2. Дубликаты и пропуски </span> </center>
#
# Проверим датасет на наличие дубликатов и пропусков.
# Для начала посмотрим на наличие явных и неявных дубликатов.

# %%
#Смотрим на кол-во явных и не явных дубликатов в датасете

explict = df.duplicated().sum()
not_explict_reg_n = df.duplicated(subset=['user_id']).sum()

print (f'Количество явных дубликатов: {explict}')
print (f'Количество дубликатов по ID: {not_explict_reg_n}')
# Out:
# Количество явных дубликатов: 0
# Количество дубликатов по ID: 0

# %% [markdown]
# Дубликатов в данных нет. Удалим не нужные нам столбцы `user_id`, `geo_location` и `seasons`.

# %%
#Удаляем столбец user_id

df = df.drop (columns = ['user_id'], axis = 1)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Продажи кофе и отток зависят от сезона, поэтому признак будет в теории полезный.
#
# Кроме геолокации у нас нет идентификаторов конкретных точек продаж, отток в зависимости от расположения точек также может быть разный, признак тоже может быть полезным.
#
# Мы можем взять сначала все потенциально полезные признаки, построить модель, оценить важность признаков по их весам, затем уже принять решение, которое будет больше опираться на информацию.
#
# Ну по id все верно, этот признак нам не нужен.

# %% [markdown]
# <div class="alert alert-info">
# Исправил. Оставили все признаки, кроме user_id для первых попыток обучения.
# </div>

# %% [markdown]
# Посмотрим на количество и долю пропусков. Из info видно, что пропуски в том, или ином количестве содержатся практически во всех столбцах датасета. Кроме того, выведим количество и долю пропусков в строках с положительным классом, чтобы иметь представление о их распределении между классами целевой переменной.

# %%
#Выведим количество и долю пропусков в столбцах нашего датасета

'''missing_data = []
for column in df.columns:
    missing_count = df [column].isna().sum()
    ratio_missing = df [column].isna().mean() * 100
    missing_count_class_1 = df [df ['churn'] == 1][column].isna().sum()
    ratio_missing_class_1 = df [df ['churn'] == 1][column].isna().mean() * 100
    if missing_count > 0:
        missing_data.append ((column, missing_count, round (ratio_missing, 2,), missing_count_class_1, round (ratio_missing_class_1, 2)))

sorted_missing_data = sorted (missing_data, key = lambda x: x[1])

for name, count, ratio, count_1, ratio_1 in sorted_missing_data:
    print (f'Количество пропусков в столбце {name}: {count} \n Доля пропусков: {ratio} \n Количество пропусков и их доля с положительным классом: {count_1} ({ratio_1})')'''
# Out:
# "missing_data = []\nfor column in df.columns:\n    missing_count = df [column].isna().sum()\n    ratio_missing = df [column].isna().mean() * 100\n    missing_count_class_1 = df [df ['churn'] == 1][column].isna().sum()\n    ratio_missing_class_1 = df [df ['churn'] == 1][column].isna().mean() * 100\n    if missing_count > 0:\n        missing_data.append ((column, missing_count, round (ratio_missing, 2,), missing_count_class_1, round (ratio_missing_class_1, 2)))\n\nsorted_missing_data = sorted (missing_data, key = lambda x: x[1])\n\nfor name, count, ratio, count_1, ratio_1 in sorted_missing_data:\n    print (f'Количество пропусков в столбце {name}: {count} \n Доля пропусков: {ratio} \n Количество пропусков и их доля с положительным классом: {count_1} ({ratio_1})')"

# %%
#Выведим количество и долю пропусков в столбцах нашего датасета
missing_table = pd.DataFrame({
    'Количество пропусков': df.isnull().sum(),
    'Доля пропусков (%)': (df.isnull().sum() / len(df) * 100).round(2),
    'Количество пропусков в классе 1' : df [df ['churn'] == 1].isnull().sum(),
    'Доля пропусков (%) в классе 1': (df [df ['churn'] == 1].isnull().sum() / len(df) * 100).round(2)

})

missing_table = missing_table.sort_values('Количество пропусков', ascending=False)
missing_table
# Out:
#                           Количество пропусков  Доля пропусков (%)  \
# seasonal_menu_tried                        989                9.46
# days_since_last_order                      945                9.04
# total_spent_last_week                      944                9.03
# subscription_status                        938                8.98
# app_opens_per_week                         896                8.57
# review_rating_last_1                       857                8.20
# median_order_value                         831                7.95
# days_since_last_promo                      731                7.00
# app_crashes_last_month                     721                6.90
# review_rating_last_10                      693                6.63
# coffee_bean_origin                         682                6.53
# seasons                                    679                6.50
# milk_preference                            668                6.39
# coffee_preference_change                   610                5.84
# order_frequency_month                      600                5.74
# avg_order_value                            583                5.58
# notifications_enabled                      537                5.14
# last_drink_size                            504                4.82
# discount_usage_rate                        397                3.80
# order_frequency_week                       388                3.71
# phone_type                                 336                3.22
# total_spent_last_month                     294                2.81
# last_coffee_type                           258                2.47
# preferred_roast                            116                1.11
# geo_location                               110                1.05
# churn                                        0                0.00
#
#                           Количество пропусков в классе 1  \
# seasonal_menu_tried                                    45
# days_since_last_order                                  58
# total_spent_last_week                                  66
# subscription_status                                    49
# app_opens_per_week                                     46
# review_rating_last_1                                   58
# median_order_value                                     58
# days_since_last_promo                                  39
# app_crashes_last_month                                 38
# review_rating_last_10                                  37
# coffee_bean_origin                                     43
# seasons                                                54
# milk_preference                                        40
# coffee_preference_change                               41
# order_frequency_month                                  48
# avg_order_value                                        44
# notifications_enabled                                  33
# last_drink_size                                        42
# discount_usage_rate                                    29
# order_frequency_week                                   21
# phone_type                                             12
# total_spent_last_month                                 22
# last_coffee_type                                       18
# preferred_roast                                         4
# geo_location                                            7
# churn                                                   0
#
#                           Доля пропусков (%) в классе 1
# seasonal_menu_tried                                0.43
# days_since_last_order                              0.56
# total_spent_last_week                              0.63
# subscription_status                                0.47
# app_opens_per_week                                 0.44
# review_rating_last_1                               0.56
# median_order_value                                 0.56
# days_since_last_promo                              0.37
# app_crashes_last_month                             0.36
# review_rating_last_10                              0.35
# coffee_bean_origin                                 0.41
# seasons                                            0.52
# milk_preference                                    0.38
# coffee_preference_change                           0.39
# order_frequency_month                              0.46
# avg_order_value                                    0.42
# notifications_enabled                              0.32
# last_drink_size                                    0.40
# discount_usage_rate                                0.28
# order_frequency_week                               0.20
# phone_type                                         0.11
# total_spent_last_month                             0.21
# last_coffee_type                                   0.17
# preferred_roast                                    0.04
# geo_location                                       0.07
# churn                                              0.00

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Удобно ли будет нам или читателю проекта смотреть на такую простыню? Быстро ли разберемся, где что? Кажется, совсем нет.
#
# Можем вывести все в одной таблице с нормальным форматированием. Например, используя что-то типа такой конструкции:
#
# ```
# missing_table = pd.DataFrame({
#     'Количество пропусков': df.isnull().sum(),
#     'Доля пропусков (%)': (df.isnull().sum() / len(df) * 100).round(2)
# })
#
# missing_table = missing_table.sort_values('Количество пропусков', ascending=False)
# missing_table
# ```

# %% [markdown]
# <div class="alert alert-info">
# Вывел информацию в виде таблицы, спасибо за подсказку!
# </div>

# %% [markdown]
# Пропуски присутствуют практически во всех столбцах датасета, захватывая строки обоих классов. При этом количество их и доля сильно разнится, максимальное кол-во пропусков в столбце `seasonal_menu_tried` - `9.46`, а минимальное в `preferred_roast` - `1.11`. В нашем случае, удаление пропущеных значений нежелательно, т.к. в данных наблюдается сильный дисбаланс классов: `629` ушедших клиентов против `9821` оставшихся, и удаление пропусков может усугубить его. Поэтому, мы обработаем пропуски - числовые колонки мы заполним мерами центральной тенденции медианой, или средним, в зависимости от разброса значений, а категориальные - модой, или индикатором `missing`.
#
# Окончательные решения по стратегиям заполнения пропусков мы примем после исследования выбросов.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# `При этом количество их и доля сильно разница` -> доля сильно разниТСя. (если я правильно понял, что имелось ввиду)

# %% [markdown]
# <div class="alert alert-info">
# Да, именно так :-) поправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отличная аргументация, хорошие решения. Можем дополнительно исследовать данные, затем уже принять окончательное решение. Верно, будем избегать утечки признаков.

# %% [markdown]
# <center> <span style="color:black"> 3. Категориальные признаки </span> </center>

# %% [markdown]
# Сначала посмотрим на количество уникальных значений в столбцах категориальных признаков и проверим на корректность и необходимость их нормализации.

# %%
# Посмотрим на кол-во в номинальных колонках

for column in ['last_coffee_type', 'preferred_roast', 'milk_preference', 'coffee_bean_origin', 'last_drink_size', 'subscription_status', 'phone_type', 'seasons', 'geo_location']:
    print(f'Количество уникальных значений в столбце {column}: {df [column].nunique()}')
    print()
# Out:
# Количество уникальных значений в столбце last_coffee_type: 3
#
# Количество уникальных значений в столбце preferred_roast: 3
#
# Количество уникальных значений в столбце milk_preference: 6
#
# Количество уникальных значений в столбце coffee_bean_origin: 6
#
# Количество уникальных значений в столбце last_drink_size: 3
#
# Количество уникальных значений в столбце subscription_status: 4
#
# Количество уникальных значений в столбце phone_type: 3
#
# Количество уникальных значений в столбце seasons: 4
#
# Количество уникальных значений в столбце geo_location: 100

# %%
#Посмотрим на корректность уникальных значений в категориальных столбцах
for column in ['last_coffee_type', 'preferred_roast', 'milk_preference', 'coffee_bean_origin', 'last_drink_size', 'subscription_status', 'phone_type', 'seasons', 'geo_location']:
    print(f"\nColumn: {column}")
    print("Unique values:", df[column].unique())
    print("Missing values count:", df[column].isna().sum())
    print("Value counts:")
    print(df[column].value_counts(dropna=False), "\n")
# Out:
# Column: last_coffee_type
# Unique values: ['blend' 'arabica' 'robusta' nan]
# Missing values count: 258
# Value counts:
# last_coffee_type
# arabica    6134
# robusta    2524
# blend      1534
# NaN         258
# Name: count, dtype: int64
#
#
# Column: preferred_roast
# Unique values: ['light' 'medium' 'dark' nan]
# Missing values count: 116
# Value counts:
# preferred_roast
# medium    3458
# light     3453
# dark      3423
# NaN        116
# Name: count, dtype: int64
#
#
# Column: milk_preference
# Unique values: ['almond' 'whole' 'oat' 'skim' 'soy' nan 'none']
# Missing values count: 668
# Value counts:
# milk_preference
# whole     2876
# oat       1982
# almond    1483
# skim      1451
# none      1015
# soy        975
# NaN        668
# Name: count, dtype: int64
#
#
# Column: coffee_bean_origin
# Unique values: ['vietnam' 'guatemala' 'brazil' 'colombia' 'kenya' nan 'ethiopia']
# Missing values count: 682
# Value counts:
# coffee_bean_origin
# ethiopia     1690
# kenya        1646
# vietnam      1635
# guatemala    1621
# brazil       1596
# colombia     1580
# NaN           682
# Name: count, dtype: int64
#
#
# Column: last_drink_size
# Unique values: ['large' 'medium' 'small' nan]
# Missing values count: 504
# Value counts:
# last_drink_size
# medium    4925
# large     2997
# small     2024
# NaN        504
# Name: count, dtype: int64
#
#
# Column: subscription_status
# Unique values: ['pro' 'none' 'premium' 'basic' nan]
# Missing values count: 938
# Value counts:
# subscription_status
# none       3803
# basic      2862
# premium    1923
# NaN         938
# pro         924
# Name: count, dtype: int64
#
#
# Column: phone_type
# Unique values: ['android' 'ios' 'web' nan]
# Missing values count: 336
# Value counts:
# phone_type
# android    4611
# ios        4502
# web        1001
# NaN         336
# Name: count, dtype: int64
#
#
# Column: seasons
# Unique values: ['summer' 'autumn' 'spring' 'winter' nan]
# Missing values count: 679
# Value counts:
# seasons
# spring    2507
# autumn    2433
# winter    2423
# summer    2408
# NaN        679
# Name: count, dtype: int64
#
#
# Column: geo_location
# Unique values: ['geo_75' 'geo_95' 'geo_25' 'geo_2' 'geo_19' 'geo_68' 'geo_3' 'geo_45'
#  'geo_15' nan 'geo_30' 'geo_93' 'geo_64' 'geo_40' 'geo_87' 'geo_17'
#  'geo_11' 'geo_94' 'geo_1' 'geo_50' 'geo_67' 'geo_51' 'geo_97' 'geo_16'
#  'geo_78' 'geo_100' 'geo_98' 'geo_43' 'geo_8' 'geo_48' 'geo_61' 'geo_74'
#  'geo_35' 'geo_59' 'geo_46' 'geo_5' 'geo_23' 'geo_91' 'geo_42' 'geo_90'
#  'geo_4' 'geo_96' 'geo_57' 'geo_71' 'geo_54' 'geo_65' 'geo_32' 'geo_14'
#  'geo_72' 'geo_29' 'geo_9' 'geo_83' 'geo_12' 'geo_76' 'geo_92' 'geo_84'
#  'geo_31' 'geo_34' 'geo_41' 'geo_18' 'geo_24' 'geo_85' 'geo_49' 'geo_69'
#  'geo_47' 'geo_86' 'geo_99' 'geo_36' 'geo_79' 'geo_26' 'geo_73' 'geo_13'
#  'geo_10' 'geo_58' 'geo_63' 'geo_82' 'geo_22' 'geo_39' 'geo_81' 'geo_21'
#  'geo_27' 'geo_33' 'geo_20' 'geo_60' 'geo_53' 'geo_88' 'geo_62' 'geo_70'
#  'geo_28' 'geo_56' 'geo_52' 'geo_66' 'geo_55' 'geo_38' 'geo_89' 'geo_37'
#  'geo_80' 'geo_6' 'geo_77' 'geo_44' 'geo_7']
# Missing values count: 110
# Value counts:
# geo_location
# geo_2     1629
# geo_3     1573
# geo_1     1532
# geo_99     117
# geo_95     110
#           ...
# geo_41      42
# geo_45      41
# geo_55      41
# geo_60      40
# geo_86      38
# Name: count, Length: 101, dtype: int64

# %% [markdown]
# В датасете содержится достаточно много категориальных признаков. Среди них есть бинарные, которые представлены в числовом формате и не требуют кодировки (seasonal_menu_tried, notifications_enabled, coffee_preference_change), а также номинальные и порядковые, представленные в строковом виде:
# - `last_coffee_type` — сорт кофе, купленный пользователем в последний раз на момент сбора данных,
# - `preferred_roast` — предпочитаемый тип обжарки,
# - `milk_preference` — предпочитаемый тип молока,
# - `coffee_bean_origin` — страна происхождения зерна,
# - `last_drink_size` — размер последнего напитка, купленного на момент сбора данных,
# - `subscription_status` — тип подписки пользователя,
# - `phone_type` — тип устройства, с которого пользователь чаще всего совершал покупки,
# - `geo_location` — идентификатор региона пользователя.
#
#
# Логистическая регрессия работает только с числовыми признаками, поэтому все перечисленые категориальные признаки формата object необходимо правильным образом закодировать. Т.к. все признаки несут небольшое количество уникальных значений, используем `One Hot Encode`r для номинальных категорий с небольшим количеством значений (< 15), для `geo_location` используем `Target Encjder` а для `subscription_status` и `last_drink_size` - эти признаки являются порядковыми - `OrdinalEncoder`.
#
# Все признаки, описывающие предпочтения клиента, тип подписки и т.д. могут так или иначе влиять на отток клиентов, учитывая наличие в сервисе тех или иных сортов кофе, повышеный сезонный спрос, или регион. Далее в анализе мы посмотрим на корреляционную матрицу признаков и проверим их на наличие мультиколлинеарности. Если какие то признаки будут сильно коррелировать друг с другом, оставим только один из них.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Здесь прекрасно по анализу категорий. Альтернативно можно было бы построить для категориальных признаков диаграммы.

# %% [markdown]
# <center> <span style="color:black"> 4. Выбросы </span> </center>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Смотри, `describe` выводили в начале проекта и там не прокомментировали. Давай уберем тогда дублирование этого. Лучше оставить в начале и там дать краткий комментарий. Иначе если дублируем какие-то действия, то как минимум это по оформлению будет визуальным шумом.

# %% [markdown]
# <div class="alert alert-info">
# Оставил `describe` только в начале.
# </div>

# %% [markdown]
# Посмотрим на распределение значений каждого из числовых признаков. Для этого построим `гистограммы` и `boxplot` для числовых признаков в датасете.

# %%
#Получаем список признаков

features = ['days_since_last_order', 'order_frequency_month', 'order_frequency_week', 'avg_order_value', 'median_order_value', 'total_spent_last_month', 
            'total_spent_last_week', 'discount_usage_rate', 'app_opens_per_week', 'review_rating_last_10', 'review_rating_last_1', 'app_crashes_last_month',
            'days_since_last_promo']
n_features = len(features)

# Подсчет необходимого количества строк 
rows = n_features  # Одна строка для каждого признака
cols = 2           # Два столбца: гистограмма и боксплот

plt.figure(figsize=(12, rows * 4))  

for idx, feature in enumerate(features):
     # Рисуем гистограмму с KDE в левом столбце
    plt.subplot(rows, cols, idx * 2 + 1)
    sns.histplot(df[feature], bins=50, alpha = 0.75, kde=True)
    plt.title(f'Гистограмма {feature}')

    # Рисуем боксплот в правом столбце
    plt.subplot(rows, cols, idx * 2 + 2)
    df.boxplot(column= feature, vert=True)  
    plt.title(f'Боксплот {feature}')

plt.tight_layout()
plt.show()

# %% [markdown]
# Сразу построим диаграмму сравнения боксплотов, для визуализации разницы масштабов признаков.

# %%
#Визуализируем масштаб данных

plt.figure (figsize= (12, 4))

# Строим boxplot (диаграмму размаха) для всех признаков

df.boxplot (column = features, rot = 90)

plt.title ('Сравнение масштабов числовых признаков')
plt.ylabel ('Значение')

plt.show ()

# %% [markdown]
# Мы видим, что во всех без исключения числовых колонках датасета присутствуют выбросы, что в той, или иной степени отражается на распределении значений. Самый экстремальный выброс при этом у признака `total_spent_last_month`, но он один и может оказаться ошибкой. В связи с тем, что это единичный случай, отфильтруем его для дальнейшего исследования.
#
# Нормальное распределение сохраняется у признаков `review_rating_last_10` и `review_rating_last_1`. `discount_usage_rate`, также, имеет хорошее распределение, незначительно смещенное вправо. Остальные признаки имеют явную ассиметрию, как правило правую и содержат в себе разное количество экстремальных значений. Исходя из специфики поставленной перед нами задачи и данных, выбросы `возможны` и несут важную информацию для модели классификации, поэтому фильтровать и удалять их мы не будем, чтобы не сместить баланс классов в данных и избежать возможных в дальнейшем ошибок обучения. Мы будем использовать масштабирование, чтобы избавится от огромного разброса значений, а также попробуем улучшить качество обучения через преобразование некоторых, наиболее дисбалансных признаков.
#
# Кроме этого, в некоторых столбцах заметны явные ошибки. Например, `отрицательные значения` в столбце `review_rating_last_1`. Рейтинг не может быть отрицательным, поэтому данную ошибку необходимо устранить. Т.к. удаление строк в нашем случае нежелательно, заменим отрицательные значения данного признака на `0`.
#
# Отрицательные значения присутствуют также в колонках `order_frequency_week, avg_order_value, median_order_value, total_spent_last_month и total_spent_last_week`, но в данном контексте такое может быть, если учитывать возможность возврата заказа и возвращения средств клиенту. Но, т.к. заказчик не уточняет данный вопрос, мы подробнее проанализируем эти признаки, посмотрим на количество отрицательных значений и примем решение.
#
# Подозрительное распределение значений присутствует в признаке `app_opens_per_week`. При `max=224.59`  `75-ый процентиль` равен `12.73`. Это может указывать на ошибку в данных, или работу ботов. К сожалению у нас нет возможности проверить достоверность этих предположений. Оставим признак как есть, но попробуем сгладить его квадратным корнем на этапе тестирования.

# %%
# Фильтруем экстремальное значение в total_spent_mobth

df = df[(df['total_spent_last_month'] < 70000) | (df['total_spent_last_month'].isna())]

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Выброс тут скорее один наблюдается в total_spent_month, его хорошо бы обработать.
#
# В остальных признаках видим абсолютно реалистичные значения, но скос вправо, что максимально ожидаемо для нашей области исследования. Во многих случаях речь идет о количестве событий в единицу времени, оно у нас описывается распределением Пуассона − вот его и видим.
#
# В задании нам толсто намекают, что влияние правого хвоста в графике можно уменьшить с помощью взятия корня признака или логарифмирования.
#
# `Оставим признак как есть, но попробуем сгладить его квадратным корнем на этапе тестирования.` - ага, верно, что это здесь проговариваешь.

# %% [markdown]
# <div class="alert alert-info">
# Добавил фильтрацию экстремального значения в total_spent_month.</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Все так по отрицательным значениям. Если их мало, можно и дропнуть, если они подозрительны.
#
# Отрицательные значения в выручке можно интерпретировать как возвраты, но и с ними не особо ясно, что делать. Тогда я бы дропнул. Но можем попробовать заполнить нулями.

# %%
# Признаки с отрицательными значениями
negative_check_cols = [
    'order_frequency_week', 
    'avg_order_value', 
    'median_order_value',
    'total_spent_last_month', 
    'total_spent_last_week'
]

# Проверяем отрицательные значения
negative_stats = {}
for col in negative_check_cols:
    if col in df.columns:
        neg_count = (df[col] < 0).sum()
        neg_percent = (neg_count / len(df)) * 100
        negative_stats[col] = {
            'count': neg_count,
            'percent': neg_percent,
            'min': df[col].min(),
            'max': df[col].max()
        }

negative_df = pd.DataFrame(negative_stats).T
print("Статистика отрицательных значений:")
print(negative_df)
# Out:
# Статистика отрицательных значений:
#                         count   percent          min           max
# order_frequency_week     83.0  0.794334    -0.169131      6.302624
# avg_order_value           2.0  0.019141   -32.075932   5901.965278
# median_order_value        2.0  0.019141   -10.353340   2189.101644
# total_spent_last_month    2.0  0.019141   -43.716463  37965.684502
# total_spent_last_week   171.0  1.636520 -2290.559468   8615.988952

# %% [markdown]
# Мы видим, что в `order_frequency_week` отрицательные значения очень маленькие, это скорее всего ошибка, или неправильное округление. Заменим в этом признаке их на `0`.
# Признаки `avg_order_value, median_order_value, total_spent_last_month` содержат чрезвычайное маленькое кол-во отрицательных строк, всего по 2 на признак, также заменим на `0`.
#
# `total_spent_last_week` в нашем случае самый проблемный. Помимо количества и доли - `171` и `1.6%`, он несет достаточно большие значения `-2290`, которые могут повлиять на обучение модели. Учитывая, что вся информация данного признака уже учтена в `total_spent_last_month`, удалим его.

# %%
# Заменим отрицательные значения на 0
def fill_0 (column):
    df [column] = np.where (df [column] < 0, 0, df [column])
    return df [column]
columns = ['order_frequency_week', 'avg_order_value', 'median_order_value', 'total_spent_last_month', 'review_rating_last_1']
for column in columns:
    df [column] = fill_0 (column)

# Удалим total_spent_last_week

df = df.drop (columns = ['total_spent_last_week'])

# %% [markdown]
# <center> <span style="color:black"> 4. Корреляции между признаками </span> </center>

# %% [markdown]
# Теперь проверим корреляции признаков друг с другом. Для этого построим корреляционную матрицу.

# %%
#Строим корреляционную матрицу

correlation_matrix = df.phik_matrix (interval_cols = ['days_since_last_order', 'order_frequency_month', 'order_frequency_week', 'avg_order_value', 'median_order_value', 'total_spent_last_month', 
            'discount_usage_rate', 'review_rating_last_10', 'review_rating_last_1', 'app_crashes_last_month', 'app_opens_per_week',
            'days_since_last_promo'])

#Для наглядности построим тепловую карту на основе нашей матрицы
plt.figure (figsize= (15, 6))
data_heatmap = correlation_matrix.drop(index='churn', columns='churn')

sns.heatmap (
    data_heatmap,
    annot=True, 
    fmt='.2f', 
    cmap='coolwarm',  
    linewidths=0.5, 
    cbar=False
)
plt.title ('Тепловая карта коэффициента phi_k')
plt.show ()

# %% [markdown]
# Среди признаков есть некоторые с выраженной корреляцией. Самые большие значения имеют пары: `order_frequency_month x order_frequency_week`, `avg_order_value x median_order_value`: `1.0` и `0.89`, соответственно. Данные корреляции необходимо более подробно изучить на графиках, чтобы принять решения по мере их устранения, т.к. такая сильная связь может негативно сказаться на обучении модели.
#
# Помимо этого, мы видим некоторое кол-во уиеренных и слабых корреляций, например `app_opens_per_week` и `total_spent_last_month` коррелируют на `0,62`, подобная корреляция может быть случайной, или иметь определенную зависимость: чем больше тратит клиент, тем чаще заходит в приложение. Также визуализируем ее и похожую корреляцию `total_spent_last_month` с средним медианным чеком, прежде принимать какие то решения.
#
# Остальные зависимости незначительны, поэтому оставим признаки без изменений.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Хорошо бы как-то прояснить, а что мы на этой матрице увидели интересного? Лучше давать комментарии к графикам сразу после них, чтобы не приходилось скроллить вверх-вниз до выводов и обратно до графиков.
#
# Для читателя проекта идеально будет, если проект будет похож на презентацию. Лучше ориентироваться на это.

# %% [markdown]
# <div class="alert alert-info">
# Добавил комментарий! </div>

# %%
#Визуализируем сильные коррелции между признаками

plt.figure (figsize=(20, 8))
plt.subplot (2, 2, 1)
plt.scatter (x=df['order_frequency_month'], 
            y=df['order_frequency_week'],
            alpha=0.7,
            color='orange',
            edgecolor='k')
plt.xlabel('order_frequency_month')
plt.ylabel('order_frequency_week')
plt.title(f'Корреляция: order_frequency_month vs order_frequency_week')

plt.subplot (2, 2, 2)
plt.scatter (x=df['avg_order_value'], 
            y=df['median_order_value'],
            alpha=0.7,
            color='orange',
            edgecolor='k')
plt.xlabel('avg_order_value')
plt.ylabel('median_order_value')
plt.title(f'Корреляция: avg_order_value vs median_order_value')

plt.subplot (2, 2, 3)
plt.scatter (x=df['app_opens_per_week'], 
            y=df['total_spent_last_month'],
            alpha=0.7,
            color='orange',
            edgecolor='k')
plt.xlabel('app_opens_per_week')
plt.ylabel('total_spent_last_month')
plt.title(f'Корреляция: app_opens_per_week vs total_spent_last_month')

plt.subplot (2, 2, 4)
plt.scatter (x=df['median_order_value'], 
            y=df['total_spent_last_month'],
            alpha=0.7,
            color='orange',
            edgecolor='k')
plt.xlabel('median_order_value')
plt.ylabel('total_spent_last_month')
plt.title(f'Корреляция: total_spent_last_month vs median_order_value')

plt.tight_layout()
plt.show ()

# %% [markdown]
# Исходя из графиков видно, что самые большие корреляции имеют пары: `order_frequency_month x order_frequency_week`, `avg_order_value x median_order_value`. Первая пара очень сильно линейно коррелирует, но оба показателя отражают схожую информацию о частоте покупок, за разные промежутки времени, это может быть сильным признаком для модели. Но, чтобы избавится от такой сильной корреляции, на этапе формирования пайплайна и преобразования признаков, мы сформируем новый признак `dif_order_frequency`, который будет представлять собой разность между количеством заказов в месяц и количеством заказов в неделю, а `order_frequency_week` удалим. Это даст модели возможность проследить снижение, или увеличение покупательной активности.
#
# Похожая ситуация с признаками меры центральной тенденции `avg_order_value` и `median_order_value`, здесь оставим только один признак: `avg_order_value`.
#
# Определенная корреляция видна у признаков `median_order_value` и `total_spent_last_month`, но, в связи с удалением признака медианного чека, дублирующего по своей сути AVG, мы уже избавляемся от этой корреляции.
#
# Остальные корреляции не значительны и, скорее всего, случайны, пока что не будем трогать эти признаки.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Вот здесь позволю себе не согласиться. Чисто математически: низкая корреляция признаков с таргетом не означает, что признак лишний. Высокая корреляция признаков между собой не означает, что пора дропать один из них.
#
# Да, в идеале мы бы хотели, чтобы все признаки высоко коррелировали с таргетом и низко коррелировали между собой, при этом в сумме давали полное объяснение изменчивости (дисперсии) таргета. Будем к этому стремиться, но отрезать на пути все, что неидеально соответствует этой схеме все-таки не стоит.
#
# Я бы по крайней мере с частью признаков не спешил с удалением. Если клиент раньше заказывал кофе часто, а в последнее время перестал, может ли это быть пизнаком оттока? Ну да, еще каким. Если мы не хотим держать в фичах высокоскоррелированные признаки, так давай создадим ровно тот, который нам нужен. Берем частоту заказов в месяц, а затем разность между частотой в неделю и частотой в месяц. Корреляция уходит, полезная информация остается.

# %% [markdown]
# <div class="alert alert-info">
# Оставил большинство признаков. Далее попробую создать признак разности. Спасибо за подсказку!</div>

# %% [markdown]
# Сразу удалим `median_order_value`, остальные признаки оставим для базового датасета, все преобразования и создания новых будем проводить на этапе валидации модели, чтобы проконтролировать ее улучшение, или снижение качества.

# %%
# Формируем финальный датасет
# Удалим мультиколлинеарные признаки

df = df.drop (columns = ['median_order_value'], axis = 1)

# %% [markdown]
# <center> <span style="color:black"> 5. Выводы </span> </center>
#
# Исходя из проведенного нами анализа, можно сделать следующие выводы.
#
# 1. В представленном датасете собрано достаточное количество актуальных данных необходимых для моделирования.
# 2. Типы данных в колонках датасета соответствуют значениям.
# 3. В данных наблюдается сильный дисбаланс классов в целевой переменной: `629` ушедших клиентов против `9821` оставшихся.
# 4. На основании анализа были удален избыточный признак: `user_id`.
# 5. В датасете содержится относительно небольшое количество пропущеных значений, разбросаных среди разных признаков. Но, в связи сильным с дисбалансом классов было принято решение не удалять их, а заменить на этапе предпоготовки данных на рассчетные значения, или индикаторы.
# 6. Большое количество категориальных признаков необходимо закодировать для правильной интерпретации моделью. Мы будем использовать `One Hot Encoder` для категорий с небольшим количеством уникальных значений (до 15), `TargetEncoder` для `geo_location` и `Ordinal Encoder` для порядковых.
# 7. В датасете присутствуют выбросы, содержащиеся практически во всех числовых признаках. В рамках нашего задания выбросы нормальны и являются неотъемлемой частью данного направления. В дальнейшем мы пременим масштабирование и попробуем несколько стратегий по работе с ними: оставим нетронутыми, преобразуем признаки, создадим новые и используем регуляризацию, после чего сравним метрики и выберем лучший подход. Были найдены ошибки в данных признаков `order_frequency_week, avg_order_value, median_order_value, total_spent_last_month, и review_rating_last_1`, где присутствовали невозможные отрицательные значения. Они были заменены на `0`.
# 8. Анализ корреляций и выбросов позволил найти и исключить ряд признаков, способных привести к проблемам в обучении модели. Были удалены признаки: `total_spent_last_week` и `median_order_value`.
#
# Посмотрим на количество потерянных нами данных.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 Отлично по оформлению.
#
# Общая идея по доработке: признаки лучше не дропать, если они хоть как-то связаны с таргетом. Всегда можем построить модель, уточниться, полезен ли признак. Лучше сделать пару лишних шагов и получить точное знание, чем удалить и пропустить оптимальную модель.
#
# А вот по подозрительным строкам (отрицательные значения), лучше убрать потенциальный шум в данных. Нам интересны чистые данные для корректных результатов прогнозирования. Здесь, если количество потенциально токсичных строк небольшое, я бы предпочтительным решением их дропнул.

# %%
# Проверим долю потерь после обработки
a, b = len(df), len(temp)
c, d = len (df.columns), len(temp.columns)
print(" Было строк в исходном датасете", b,
      '\n', "Осталось строк в датасете после обработки", a,
      '\n', "Удалено строк в датасете после обработки", b-a,
      '\n', "Процент потерь", round((b-a)/b*100, 2),
      '\n', "Было столбцов в исходном датасете:", d,
      '\n', "Стало в преобразованном:", c)
# Out:
#  Было строк в исходном датасете 10450
#  Осталось строк в датасете после обработки 10449
#  Удалено строк в датасете после обработки 1
#  Процент потерь 0.01
#  Было столбцов в исходном датасете: 27
#  Стало в преобразованном: 24

# %% [markdown]
# Процент потерь составил `0.01`, это незначительный процент, который не скажется на качестве обучения модели. В процессе исследовательского анализа мы сократили поле признаков с `27` до `24`, удалив `3` избыточных признака, которые несли за собой ошибки, или возможные проблемы с мультиколлинеарностью, смещением весов и переобучением.
#
# На данном этапе можем приступать к предобработке данных.

# %% [markdown]
# ## <center> <span style="color:black"> Этап 3. Предобработка данных </span> </center>

# %% [markdown]
# Сначала разделим датасет на признаки - X - и целевую переменную - y.

# %%
# Разделяем признаки и целевую переменную

X = df.drop(columns = 'churn')
y = df ['churn']

# %% [markdown]
# Далее разделим данные на две выборки `80` к `20`: `обучающую-валидационную` и `тестовую`. При разделении будем учитывать дисбаланс классов, для этого применим `стратификацию`.

# %%
# Делим данные на train_val и test

X_train_val, X_test, y_train_val, y_test = train_test_split (
    X, y,
    test_size = 0.20,
    stratify = y,
    random_state = RANDOM_STATE
)

# %% [markdown]
# Далее создадим `пайплайны` по предобработке данных и объединим их в единый трансформер.
#
# В числовых признаках мы заменим пропуски `медианным значением`, оно более устойчиво к выбросам и поможет нам сгладить данные. Также проведем масштабирование методом `Standart Sceller` для нормализации масштаба данных.
#
# Категориальные признаки в нашем датасете представлены в трех вариантах, это бинарные признаки: `seasonal_menu_tried`, `notifications_enabled` и `coffee_preference_change`, номинальные с небольшим количеством категорий и `geo_location`, где присутствует множество значений. Пропуски в бинарных категориях мы заменим на `моду`, а в номинальных на индикатор `missing`. Также закодируем номинальные категориальные значения с помощью `One Hot Encoder`. `Ordinal Encoder` для признаков `subscription_status` и `last_drink_size`, в которых значений имеют строгий порядок и `TargetEncoder` для `geo_location`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 отлично

# %%
df.head (5)
# Out:
#    days_since_last_order  order_frequency_month  order_frequency_week  \
# 0                    0.0              12.942519                   NaN
# 1                    2.0               1.569146              0.214494
# 2                   11.0               2.996666              0.771864
# 3                    0.0               4.299255              1.210480
# 4                    3.0               7.249864              1.761027
#
#    avg_order_value  total_spent_last_month  discount_usage_rate  \
# 0       316.833872             3089.991009             0.337031
# 1       780.135158              998.380941             0.547659
# 2       682.636256             1328.140204             0.120258
# 3      2115.487425             2999.628366                  NaN
# 4      3519.602170             8377.729478             0.074990
#
#   last_coffee_type preferred_roast milk_preference  seasonal_menu_tried  \
# 0            blend           light          almond                  NaN
# 1          arabica           light           whole                  1.0
# 2          arabica          medium             oat                  1.0
# 3          robusta          medium            skim                  0.0
# 4          robusta            dark          almond                  1.0
#
#   coffee_bean_origin last_drink_size subscription_status  app_opens_per_week  \
# 0            vietnam           large                 pro           30.468321
# 1          guatemala          medium                none                 NaN
# 2          guatemala           small             premium           17.895637
# 3             brazil          medium                none           11.405533
# 4           colombia          medium                none           15.948239
#
#    notifications_enabled  review_rating_last_10  review_rating_last_1  \
# 0                    1.0               5.176792              3.302238
# 1                    1.0               4.392991                   NaN
# 2                    1.0               4.977712              4.379219
# 3                    1.0               3.712526              3.043618
# 4                    0.0               4.528271              5.642993
#
#    app_crashes_last_month seasons  days_since_last_promo phone_type  \
# 0                     NaN  summer                    6.0    android
# 1                     0.0  autumn                   16.0        ios
# 2                     0.0  spring                   11.0        web
# 3                     0.0  summer                    3.0    android
# 4                     1.0  winter                   14.0        ios
#
#    coffee_preference_change geo_location  churn
# 0                       0.0       geo_75      1
# 1                       0.0       geo_95      0
# 2                       1.0       geo_25      0
# 3                       0.0        geo_2      0
# 4                       0.0       geo_19      1

# %%
# Выделим числовые и категориальные признаки

num_features = ['days_since_last_order', 'order_frequency_month', 'order_frequency_week', 'avg_order_value', 'total_spent_last_month', 
            'discount_usage_rate', 'review_rating_last_10', 'review_rating_last_1', 'app_crashes_last_month', 'app_opens_per_week',
            'days_since_last_promo']
cat_features = ['last_coffee_type', 'preferred_roast', 'milk_preference', 'coffee_bean_origin', 
                'phone_type', 'seasons']
ordinal_features = ['last_drink_size', 'subscription_status']
# Категории для порядковых признаков
drink_size_categories = ['missing', 'small', 'medium', 'large']
subscription_categories = ['none', 'basic', 'pro', 'premium']

bin_features = ['seasonal_menu_tried', 'notifications_enabled', 'coffee_preference_change']
geo_feature = ['geo_location']
# Создадим пайплайны по их обработке

# Для числовых признаков
num_pipeline = Pipeline (steps = [
    ('обработка пропусков', SimpleImputer (strategy = 'median')),
    ('масштабирование', StandardScaler ())
])

# Для категориальных
cat_pipeline = Pipeline (steps=[
    ('обработка пропусков', SimpleImputer (strategy = 'constant', fill_value= 'missing')),
    ('кодирование признаков', OneHotEncoder(sparse_output=False, handle_unknown='ignore'))
])

# Для порядковых признаков
ordinal_pipeline = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('encoder', OrdinalEncoder(
        categories=[drink_size_categories, subscription_categories],
        handle_unknown='use_encoded_value',
        unknown_value=-1  
    ))
])

# Для бинарных
bin_pipeline = Pipeline (steps=[
    ('обработка пропусков', SimpleImputer (strategy = 'most_frequent')),
])

# Для geo_location
geo_pipeline = Pipeline (steps=[
    ('обработка пропусков', SimpleImputer (strategy = 'constant', fill_value= 'missing')),
    ('кодирование признаков', TargetEncoder ())
])

# %%
# Объединяем все пайплайны в один ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('num', num_pipeline, num_features),
    ('cat', cat_pipeline, cat_features),
    ('ord', ordinal_pipeline, ordinal_features),
    ('geo', geo_pipeline, geo_feature),
    ('bin', bin_pipeline, bin_features)
])

# %% [markdown]
# ## <center> <span style="color:black"> Этап 4. Обучение модели </span> </center>

# %% [markdown]
# Обучим две модели, классическую `Логистическую регрессию` и базовую модель - `DummyClassifier`. Для обучения будем использовать `кросс-валидацию`, чтобы максимально полно и эффективно использовать наши данные и надежно оценить реализацию моделей.
#
# Метрики, по которым будем сравнивать качество моделей это, `Log Loss` и `PR-AUC`. Log Loss покажет насколько хорошо модель оценивает вероятность ухода клиента, что важно нам для оценки и выбора наилучшей, а PR-AUC критически важен для этой задачи, т.к. уходящих клиентов значительно меньше, чем остающихся, ведь данные не сбалансированы, а PR-AUC покажет, насколько хорошо модель выделяет положительные классы из общей массы примеров.

# %%
# Формируем пайплайн базовой модели

pipeline_base = Pipeline (steps= [
    ('preprocessor', preprocessor),
    ('model', DummyClassifier (strategy = 'stratified', random_state=RANDOM_STATE))
])

# ФОрмируем пайплайн основной модели

pipeline_log = Pipeline (steps = [
    ('preprocessor', preprocessor),
    ('model', LogisticRegression (random_state=RANDOM_STATE))
])

# %%
# Проведем кросс валидацию базовой модели - Dummy Classifier

# Задаем количество фолдов
N_FOLDS = 5

kfold = StratifiedKFold (n_splits = N_FOLDS, shuffle = True, random_state = RANDOM_STATE)
scoring = ['neg_log_loss', 'average_precision']

# Выполняем кросс-валидацию базовой модели

cv_results_base = cross_validate(
    estimator=pipeline_base,
    X = X_train_val,
    y = y_train_val,
    scoring = scoring,
    cv = kfold
)
base_means = {
    'log_loss' : round (np.mean (- cv_results_base ['test_neg_log_loss']), 3),
    'pr_auc' : round (np.mean (cv_results_base ['test_average_precision']), 3)    
}
print("Результаты базовой модели (средние значения):")
print("-" * 50)
print(f"Log Loss: {base_means['log_loss']}")
print(f"PR-AUC:   {base_means['pr_auc']}\n")

# Выполняем кросс-валидацию осноной модели

cv_results_log = cross_validate(
    estimator=pipeline_log,
    X = X_train_val,
    y = y_train_val,
    scoring = scoring,
    cv = kfold
)
log_means = {
    'log_loss' : round (np.mean (- cv_results_log ['test_neg_log_loss']), 3),
    'pr_auc' : round (np.mean (cv_results_log ['test_average_precision']), 3)    
}
print("Результаты основной модели (средние значения):")
print("-" * 50)
print(f"Log Loss: {log_means['log_loss']}")
print(f"PR-AUC:   {log_means['pr_auc']}\n")
# Сравнение моделей
# Out:
# Результаты базовой модели (средние значения):
# --------------------------------------------------
# Log Loss: 4.157
# PR-AUC:   0.061
#
# Результаты основной модели (средние значения):
# --------------------------------------------------
# Log Loss: 0.125
# PR-AUC:   0.656

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 Здесь все верно. Вернем признаки, метрика чуть-чуть подрастет (предположительно)

# %% [markdown]
# Исходя из результатов метрик видно, что базовая модель работает очень плохо, она не предсказывает уход клиента, а выдает наиболее часто встречающийся класс. Ее PR-AUC чрезвычайно мал - `0.06`, а Log Loss, наоборот велик - `4.165`. Основная модель логистической регрессии же предсказыввает метки классов в `11 раз лучше`. Это не плохой результат и хорошее начало обучения модели. Попробуем нормализовать данные, поработать с признаками и гиперпараметрами, чтобы улучшить качество наших предсказаний.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 результат неплохой

# %% [markdown]
# ## <center> <span style="color:black"> Этап 5. Создание новых признаков </span> </center>

# %% [markdown]
# В нашем датасете практически все признаки имеют выбросы и сильную правосторонню ассиметрию. Поэтому попробуем преобразовать их, сгладив тем самым распределение значений.
#
# Применем `логарифмическое преобразование` для признаков с сильной правой ассиметрией: `total_spent_last_month`, `avg_order_value`, `days_since_last_promo` и `app_opens_per_week` т.к. у них самый экстремальный разброс значений, подобное преобразование поможет сгладить диапазон и улучшить интерпретацию данных признаков моделью.
#
# Также преобразуем признаки с более умеренным разбросом: `days_since_last_order `. К значениям данного признака датасета применим `квадратный корень`. Квадратичное преобразование используется для смягчения эффекта слегка несимметричных распределений. Оно менее агрессивно, чем логарифмическое, и подходит для признаков с меньшим уровнем асимметрии.
#
# Признак `app_crashes_last_month` содержит достаточно маленькие значения с небольшим разбросом, но является одним из ключевых в нашем случае. Возведем его в `квадрат`, чтобы усилить влияние данного значения на предсказания.
#
# Как и писали ранее, добавим новый признак: `dif_order_frequency` показывающий разницу между количеством заказов в месяц и неделю, чтобы помочь модели найти правильные зависимости, а также избавиться от второго, сильно коррелирующего признака.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 Супер, все логично.

# %%
# Создадим функцию преобразования, которую в дальнейшем включим в пайплайн

def create_enhanced_features(X):
    
    X_enhanced = X.copy()
     #1. Логарифм 
    X_enhanced ['total_spent_last_month_log'] = np.log1p (X_enhanced ['total_spent_last_month'])
    X_enhanced ['avg_order_value_log'] = np.log1p (X_enhanced ['avg_order_value'])
    X_enhanced ['days_since_last_promo_log'] = np.log1p (X_enhanced ['days_since_last_promo'])
    X_enhanced ['app_opens_per_week_log'] = np.log1p (X_enhanced ['app_opens_per_week'])


    # 2. Квадратный корень 
    X_enhanced ['days_since_last_order_sqrt'] = np.sqrt (X_enhanced ['days_since_last_order'])

    # 3. Возведение в квадрат
    X_enhanced ['app_crashes_last_month_squared'] = X_enhanced ['app_crashes_last_month'] ** 2

    # 4. Создаем новый признак

    X_enhanced ['dif_order_frequency'] = X_enhanced ['order_frequency_month'] - X_enhanced ['order_frequency_week']

    # Удаляем исходные признаки
    columns_to_drop = ['total_spent_last_month', 'avg_order_value', 'days_since_last_promo', 'days_since_last_order', 'app_opens_per_week', 'app_crashes_last_month', 'order_frequency_week']

    X_enhanced = X_enhanced.drop (columns = columns_to_drop, axis = 1)
    return X_enhanced

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 Оооокк.
#
# Здесь можно смотреть по ситуации, что нам интереснее, делать расчеты в пайплайне на лету, либо рассчитать и добавить в таблицу новые признаки и дальше уже выбирать, с чем обучаем модель. Я чаще выбираю второй вариант, он как будто бы экономит время на расчеты, если будем пробовать несколько вариантов с признаками.
#
# Ну и всегда можно из таблицы построить гистограммки, посмотреть, насколько успешным оказалось логарифмирование, стали ли наши распределения плотности более похожи на нормальное распределение.

# %% [markdown]
# Обновим трансформер предобработки датасета учитывая внесенные изменения и заново проведем кросс-валидацию и сравнение метрик качества, но уже на обновленном датасете с новыми признаками.

# %%
# Обновим списки признаков с учетом изменений
num_features_enhanced = ['days_since_last_order_sqrt', 'dif_order_frequency', 'days_since_last_promo_log', 'order_frequency_month', 'avg_order_value_log', 'total_spent_last_month_log', 
           'discount_usage_rate', 'review_rating_last_10', 'review_rating_last_1', 'app_crashes_last_month_squared', 'app_opens_per_week_log']

# Обновляем трансформер
preprocessor_enhanced = ColumnTransformer (
    transformers = [
        ('num', num_pipeline, num_features_enhanced),
        ('cat_1', cat_pipeline, cat_features),
        ('ord', ordinal_pipeline, ordinal_features),
        ('bin', bin_pipeline, bin_features)
    ]
)
# Формируем обновленный пайплайн основной модели

pipeline_log_enhanced = Pipeline (steps = [
    ('feature_engineering', FunctionTransformer(create_enhanced_features, validate=False)),
    ('preprocessor', preprocessor_enhanced),
    ('model', LogisticRegression (random_state=RANDOM_STATE))
])

# Выполняем кросс-валидацию основной модели на обновленных данных

cv_results_log_enhanced = cross_validate(
    estimator=pipeline_log_enhanced,
    X = X_train_val,
    y = y_train_val,
    scoring = scoring,
    cv = kfold
)
log_means_enhanced = {
    'log_loss' : round (np.mean (- cv_results_log_enhanced ['test_neg_log_loss']), 3),
    'pr_auc' : round (np.mean (cv_results_log_enhanced ['test_average_precision']), 3)    
}
print("Результаты обновленной модели (средние значения):")
print("-" * 50)
print(f"Log Loss: {log_means_enhanced['log_loss']}")
print(f"PR-AUC:   {log_means_enhanced['pr_auc']}\n")

# Сравнение моделей
print("\nСравнение моделей:")
print("-" * 50)
print(f"{'Метрика':<12} {'Базовая':<12} {'Основная':<12} {'Улучшенная':<12} {'Изменение':<10}")
print("-" * 50)

for metric in ["log_loss", "pr_auc"]:
    # Получаем значения для каждой модели
    base_val = base_means[metric]
    log_val = log_means[metric]
    log_enhanced_val = log_means_enhanced[metric]  
    
    # Для log_loss уменьшение означает улучшение
    if metric == "log_loss":
        # Сравниваем улучшенную с основной
        change = log_val - log_enhanced_val  # Положительное значение = улучшение
        change_str = f"{change:+.3f}"
    else:  # Для PR-AUC увеличение означает улучшение
        change = log_enhanced_val - log_val  # Положительное значение = улучшение
        change_str = f"{change:+.3f}"
    
    print(
        f"{metric.upper():<12} {base_val:<12.3f} {log_val:<12.3f} {log_enhanced_val:<12.3f} {change_str:<10}"
    )
# Out:
# Результаты обновленной модели (средние значения):
# --------------------------------------------------
# Log Loss: 0.116
# PR-AUC:   0.685
#
#
# Сравнение моделей:
# --------------------------------------------------
# Метрика      Базовая      Основная     Улучшенная   Изменение
# --------------------------------------------------
# LOG_LOSS     4.157        0.125        0.116        +0.009
# PR_AUC       0.061        0.656        0.685        +0.029

# %% [markdown]
# Метрики модели улучшились. Особенно вырос PR_AUC, с `0.656` до `0.685`, что означает, что с преобразованными признаками модель лучше улавливает закономерности и точнее интерпретирует классы.
#
# Теперь посмотрим на коэффициенты модели, чтобы определить какие из признаков она считает важными, а какие нет.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 ЧТД. Логарифмирование дейстивтельно очень хорошо помогло.

# %%
model = pipeline_log_enhanced
model.fit(X_train_val, y_train_val)

# Сохраним названия признаков
feature_names = pipeline_log_enhanced.named_steps['preprocessor'].get_feature_names_out()

# Веса логистической регрессии
coefs = model.named_steps['model'].coef_[0]
 

coef_df = pd.DataFrame({
    "feature": feature_names,
    "coef": coefs,
    "abs_coef": np.abs(coefs),
    "sign": np.where(coefs >= 0, "+", "−")
})

# Отсортируем по модулю коэффициента — самые "сильные" веса будут сверху.
coef_df_sorted = coef_df.sort_values(by="abs_coef", ascending=False).reset_index(drop=True)

print("Признаки по силе влияния (по модулю коэффициента):")
print(coef_df_sorted)
# Out:
# Признаки по силе влияния (по модулю коэффициента):
#                                 feature      coef  abs_coef sign
# 0   num__app_crashes_last_month_squared  1.803667  1.803667    +
# 1           num__app_opens_per_week_log  0.771737  0.771737    +
# 2        cat_1__preferred_roast_missing -0.501531  0.501531    −
# 3            num__order_frequency_month  0.468587  0.468587    +
# 4                cat_1__seasons_missing  0.406571  0.406571    +
# 5              bin__seasonal_menu_tried -0.382833  0.382833    −
# 6           cat_1__milk_preference_none -0.335928  0.335928    −
# 7       cat_1__last_coffee_type_missing  0.327639  0.327639    +
# 8       cat_1__last_coffee_type_arabica -0.310618  0.310618    −
# 9         cat_1__milk_preference_almond  0.301805  0.301805    +
# 10            cat_1__phone_type_android  0.295022  0.295022    +
# 11          cat_1__preferred_roast_dark  0.289458  0.289458    +
# 12    cat_1__coffee_bean_origin_missing  0.251953  0.251953    +
# 13                cat_1__phone_type_web -0.233757  0.233757    −
# 14      num__total_spent_last_month_log -0.208205  0.208205    −
# 15                cat_1__seasons_spring -0.195245  0.195245    −
# 16        cat_1__last_coffee_type_blend -0.180281  0.180281    −
# 17      cat_1__last_coffee_type_robusta  0.171196  0.171196    +
# 18   cat_1__coffee_bean_origin_colombia -0.160632  0.160632    −
# 19        cat_1__preferred_roast_medium  0.155073  0.155073    +
# 20       num__days_since_last_promo_log  0.154413  0.154413    +
# 21             ord__subscription_status  0.131103  0.131103    +
# 22       cat_1__milk_preference_missing  0.130781  0.130781    +
# 23            cat_1__phone_type_missing -0.129698  0.129698    −
# 24      cat_1__coffee_bean_origin_kenya -0.124402  0.124402    −
# 25          cat_1__milk_preference_skim -0.112820  0.112820    −
# 26            num__review_rating_last_1  0.102900  0.102900    +
# 27           cat_1__milk_preference_oat  0.101033  0.101033    +
# 28           bin__notifications_enabled -0.099312  0.099312    −
# 29   cat_1__coffee_bean_origin_ethiopia  0.097162  0.097162    +
# 30        bin__coffee_preference_change -0.091239  0.091239    −
# 31                cat_1__phone_type_ios  0.076370  0.076370    +
# 32                cat_1__seasons_winter -0.076046  0.076046    −
# 33             num__avg_order_value_log  0.074789  0.074789    +
# 34                cat_1__seasons_autumn -0.065307  0.065307    −
# 35         cat_1__preferred_roast_light  0.064937  0.064937    +
# 36                cat_1__seasons_summer -0.062037  0.062037    −
# 37           num__review_rating_last_10 -0.061393  0.061393    −
# 38         cat_1__milk_preference_whole -0.048983  0.048983    −
# 39  cat_1__coffee_bean_origin_guatemala -0.044183  0.044183    −
# 40                 ord__last_drink_size  0.036852  0.036852    +
# 41      num__days_since_last_order_sqrt  0.033362  0.033362    +
# 42           cat_1__milk_preference_soy -0.027950  0.027950    −
# 43    cat_1__coffee_bean_origin_vietnam -0.023689  0.023689    −
# 44     cat_1__coffee_bean_origin_brazil  0.011728  0.011728    +
# 45             num__discount_usage_rate -0.011193  0.011193    −
# 46             num__dif_order_frequency -0.010981  0.010981    −

# %% [markdown]
# Видно, что наиболее сильное влияние на вероятность положительного класса, а следовательно на уход клиента, оказывают два признака: количество сбоев приложения в месяц и кол-во открытий приложения в месяц. Кроме того, сколичество заказов в месяц, также достаточно сильно влияет на отток.
#
# Получается, что пользователи в основной массе уходят из-за стабильности работы приложения. Количество запусков и заказов в месяц можно использовать для более точного прогнозирования.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 Кстати, количество сбоев придложения можно наоборот возвести в квадрат. Мы предполагаем, что если сбоев 2-3, то клиент будет реагировать не очень остро, а вот если больше, то с каждым новым сбоем вероятность отказа от использования приложения будет расти квадратично. Если так, то и возведение признака в квадрат будет более точно моделировать нашу реальность.

# %% [markdown]
# <div class="alert alert-info">
# Думал так сделать еще в первый раз, но почему-то побоялся.... Сейчас добавил возведение в квадрат!</div>

# %% [markdown]
# Далее попробуем поэкспериментировать с гиперпараметрами для дальнейшего улучшения предсказательной способности.

# %% [markdown]
# ## <center> <span style="color:black"> Этап 6. Эксперименты с гиперпараметрами </span> </center>

# %% [markdown]
# Теперь попробуем поэкспериментировать с гиперпараметрами.
# Мы посмотрим на важный параметр - `параметр C`, который поможет нам подобрать наилучшую регуляризацию.
#
# Сначала проведем несколько итераций с разными значениями `параметра С`.

# %%
# Список значений C, которые проверим
C_values = [0.001, 0.01, 0.1, 1, 10, 100]

# Цикл для проверки всех вариантов
for c in C_values:
    pipeline_exp = Pipeline (steps = [
    ('feature_engineering', FunctionTransformer(create_enhanced_features, validate=False)),
    ('preprocessor', preprocessor_enhanced),
    ('model', LogisticRegression (C=c, random_state=RANDOM_STATE))
])
    cv_results_exp = cross_validate(
    estimator=pipeline_exp,
    X = X_train_val,
    y = y_train_val,
    scoring = scoring,
    cv = kfold
)
    log_means_exp= {
        'log_loss' : round (np.mean (- cv_results_exp ['test_neg_log_loss']), 3),
        'pr_auc' : round (np.mean (cv_results_exp ['test_average_precision']), 3)    
}
    
     # Выводим результаты для текущего C
    print(f"C = {c}:")
    print(f"  Log Loss: {log_means_exp['log_loss']}")
    print(f"  PR-AUC:   {log_means_exp['pr_auc']}")
    print("-" * 30)
# Out:
# C = 0.001:
#   Log Loss: 0.157
#   PR-AUC:   0.688
# ------------------------------
# C = 0.01:
#   Log Loss: 0.118
#   PR-AUC:   0.694
# ------------------------------
# C = 0.1:
#   Log Loss: 0.115
#   PR-AUC:   0.69
# ------------------------------
# C = 1:
#   Log Loss: 0.116
#   PR-AUC:   0.685
# ------------------------------
# C = 10:
#   Log Loss: 0.117
#   PR-AUC:   0.683
# ------------------------------
# C = 100:
#   Log Loss: 0.117
#   PR-AUC:   0.683
# ------------------------------

# %%
# Запишем метрики лучшей модели в словарь
log_means_exp_up = {
        'log_loss' : 0.125,
        'pr_auc' : 0.693    
}

# %% [markdown]
# Мы ориентируемся на метрику `PR-AUC` в нашем случае, так как она показывает насколько хорошо модель выделяет положительный класс из общей массы примеров.
#
# Лучший результат показала модель, у которой `параметр С` = `0,01` PR-AUC у данной версии составляет `0.694`. Именно эту модель выберем для финального теста.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 Ок, единственное, если используем кросс-валидацию, удобнее взять сетку параметров для гридсеча, нежели прогонять все в цикле.

# %% [markdown]
# <div class="alert alert-info">
# В уроках такого не было :-(, пока делал проект не встречал.. Если сможешь подскажи, пожалуйста, что ты имел в виду? </div>

# %% [markdown]
# ## <center> <span style="color:black"> Этап 7. Подготовка финальной модели </span> </center>
# Объединим лучшую конфигурацию гиперпараметров с оптимальным набором признаков. Обучим модель на всех данных для кросс-валидации и проведем финальную оценку на отложенной тестовой выборке.

# %%
# Финальный вариант пайплайна

final_pipeline = Pipeline (steps = [
    ('feature_engineering', FunctionTransformer(create_enhanced_features, validate=False)),
    ('preprocessor', preprocessor_enhanced),
    ('model', LogisticRegression (C=0.01, random_state=RANDOM_STATE))
])

# Обучаем модель
final_pipeline.fit (X_train_val, y_train_val)

# Получаем предсказания вероятностей и классов на тестовой выборке
y_test_pred_proba = final_pipeline.predict_proba (X_test)[:, 1]
y_test_proba = final_pipeline.predict (X_test)

# Рассчитываем финальные метрики

final_log_loss = log_loss (y_test, y_test_pred_proba)
final_pr_auc = average_precision_score (y_test, y_test_pred_proba)

print("Финальные результаты на тестовой выборке:")
print("-" * 45)
print(f"Log Loss: {final_log_loss:.3f}")
print(f"PR-AUC:   {final_pr_auc:.3f}")

print("\nСравнение с кросс-валидацией:")
print("-" * 45)
print(f"{'Метрика':<12} {'CV':<12} {'Test':<12} {'Разница':<10}")
print("-" * 45)

test_results_final = {"log_loss": final_log_loss, "pr_auc": final_pr_auc}

for metric in ["log_loss", "pr_auc"]:
    cv_mean = log_means_exp_up[metric]
    test_score = test_results_final[metric]
    diff = test_score - cv_mean

    print(f"{metric.upper():<12} {cv_mean:<12.3f} {test_score:<12.3f} {diff:+.3f}")
# Out:
# Финальные результаты на тестовой выборке:
# ---------------------------------------------
# Log Loss: 0.109
# PR-AUC:   0.743
#
# Сравнение с кросс-валидацией:
# ---------------------------------------------
# Метрика      CV           Test         Разница
# ---------------------------------------------
# LOG_LOSS     0.125        0.109        -0.016
# PR_AUC       0.693        0.743        +0.050

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 Все отлично.

# %% [markdown]
# <div class="alert alert-info">
# ДА! Модель действительно улучшилась! Спасибо огромное за комментарии! Надеюсь теперь проект ствл удовлетворителен :-)</div>

# %% [markdown]
# ## <center> <span style="color:black"> Этап 8. Отчёт о проделанной работе </span> </center>
#
# Проанализируйте итоговые метрики модели и факторы, которые на них повлияли. Составьте описание, выделив наиболее важные факторы.

# %% [markdown]
# Мы достигли значительных успехов в повышении эффективности модели. Основной показатель — метрику `PR-AUC` — удалось увеличить в двенадцать раз по сравнению с простым случайным выбором до `0.743`. Ее значение выросло с начального уровня до впечатляющих `0.743`, демонстрируя существенный прогресс. Таким образом, наша модель теперь гораздо точнее определяет клиентов, склонных покинуть сервис, что крайне ценно для заказчика. Ведь своевременное выявление потенциальных ушедших клиентов позволит направить маркетинговые бюджеты на эффективные мероприятия по удержанию, повышая общую эффективность бизнеса.
#
# Кроме того, ключевая метрика качества классификационной модели — `Log-Loss` — тоже продемонстрировала позитивную динамику, уменьшившись с `0.125` до `0.109`. Такое снижение говорит о том, что прогнозы модели стали заметно ближе к реальности, снижая уровень неопределенности и увеличивая надежность наших решений.
#
# Полученный успех стал возможным благодаря комплексной работе над качеством набора данных. Во-первых, проведен тщательный исследовательский анализ, который помог точно выбрать ключевые признаки, убрать лишние и малозначимые переменные, устранить некорректные или аномальные значения, а также решить проблему мультиколлинеарности, когда одни признаки тесно связаны с другими. Эти шаги позволили существенно улучшить качество исходных данных.
#
# Во-вторых, были применены специальные преобразования для стабилизации масштаба и уменьшения воздействия чрезмерно крупных значений. Например, для ряда признаков было выполнено логарифмическое преобразование или взятие квадратного корня, что позволило сгладить большие расхождения в значениях и сделать модель более устойчивой.
#
# Наконец, важным этапом стало оптимальное определение гипер-параметров. Важнейший фактор успеха — правильная настройка `коэффициента регуляризации C`, который оказался оптимальным на уровне `0.01`.
#
# Таким образом, проделанная работа позволила добиться выдающихся результатов, подтвердив готовность нашей модели к применению в реальных условиях для эффективного прогнозирования оттока клиентов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 По комментариям и выводам в проекте также все здорово.
#
# Хорошие логичные тексты, все важное, ничего лишнего.

# %% [markdown]
# ## <center> <span style="color:black"> Этап 9. Сохранение модели для продакшена </span> </center>
#
# Сохраним итоговую модель и пайплайн предобработки и проверим ее на работоспособность.

# %%
# Сохраняем артефакты  и модель
model_name = f'final_model_1_0_2026_01_28.pkl'
# Сохраняйте метаданные вместе с моделью
metadata = {
    'model_version': '1.0',
    'training_date': '2026-01-28',
    'log_loss': 0.118,
    'pr_auc' : 0.730,
    'features': [X_test.columns]
}

joblib.dump({
    'model': final_pipeline,
    'metadata': metadata
}, model_name)

 # Загрузим модель и убедимся, что она работает

# Загружаем модель и артефакты
loaded_model = joblib.load('final_model_1_0_2026_01_28.pkl')
pipeline = loaded_model ['model']
artefacts = loaded_model ['metadata']
# Делаем предсказания

predictions = pipeline.predict (X_test)
print(predictions)

# Выгружаем артефакты

print (artefacts)
# Out:
# [0 0 0 ... 0 0 0]
# {'model_version': '1.0', 'training_date': '2026-01-28', 'log_loss': 0.118, 'pr_auc': 0.73, 'features': [Index(['days_since_last_order', 'order_frequency_month',
#        'order_frequency_week', 'avg_order_value', 'total_spent_last_month',
#        'discount_usage_rate', 'last_coffee_type', 'preferred_roast',
#        'milk_preference', 'seasonal_menu_tried', 'coffee_bean_origin',
#        'last_drink_size', 'subscription_status', 'app_opens_per_week',
#        'notifications_enabled', 'review_rating_last_10',
#        'review_rating_last_1', 'app_crashes_last_month', 'seasons',
#        'days_since_last_promo', 'phone_type', 'coffee_preference_change',
#        'geo_location'],
#       dtype='object')]}

# %% [markdown]
# Ссылка на проект `git_hub`:
#
# https://github.com/Smike1994/project_sprint_11

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# В задании нас просят загрузить модель в репозиторий (например, на гитхаб), добавить к ней документ с зависимостями типа requirements.txt и дать ссылку.
#
# (Этот документ мы можем сформировать автоматически через `pip freeze > requirements.txt`)

# %% [markdown]
# <div class="alert alert-info">
# Добавил ссылку на проект в гитхабе!</div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Спасибо за твой проект! Прекрасное оформление, отлично по структуре, практически ничего лишнего и избыточного, при этом есть все необходимое для исследования. Такой проект легко читать и проверять.
#
# **Отмечу положительные моменты проекта🚀**
#
# * Хорошая схема проекта.
# * Отличные решения в коде, все оптимально, прозрачно, понятно.
# * Есть пояснения и аргументация решений.
# * Очень хооршие комментарии, все логично.
#
# **На что стоит обратить внимание🤔**
#
# * Важно не удалять признаки, которые в теории могут быть важными. Возможно, твои решения, или часть из них, полностью верные, но пока мы этого не знаем, и если просто все удалим без проверки, то и не узнаем. Лучше обучить модель с признаками как есть, вывести важность признаков, уточниться, что можем удалить, попробовать обучить без лишних заново, сравнить качество и знать наверняка, что приняли верное решение. Пары признаков с высокой корреляцией можем преобразовать, взяв вместо одного в паре разность признаков. Так сохраним полезную информацию о динамике (клиент раньше покупал часто, теперь редко −  информация о таком изменении может быть полезной для определения оттока).
# * Это и остальные замечания я также написал по ходу проекта.
#
#
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉
#
#
# </div>
